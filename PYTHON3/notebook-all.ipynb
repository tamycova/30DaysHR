# %% [markdown]
# #[30 Days of Code](https://www.hackerrank.com/30-days-of-code)

# %% [markdown]
# ##[Day 0: Print Hello World!](https://www.hackerrank.com/contests/30-days-of-code/challenges/day-0-print-hello-world)

# %%
print "Hello World.\nWelcome to 30 Days of Code."
# Out:
# Hello World.
# Welcome to 30 Days of Code.

# %% [markdown]
# ##[Day 2: Arithmetic!](https://www.hackerrank.com/contests/30-days-of-code/challenges/day-2-arithmetic)

# %%
M = float(raw_input())
T = int(raw_input())
X = int(raw_input())

print "The final price of the meal is $" + str(round((M) + (M*T*0.01) + (M*X*0.01))) + "."
# Out:
# 12.00
# 20
# 8
# The final price of the meal is $15.0.

# %% [markdown]
# ##[Day 3: If-Else Statements!](https://www.hackerrank.com/contests/30-days-of-code/challenges/day-3-if-statements)

# %%
print("Not "*(int(input().strip())in{2,4}|set(range(22,101,2)))+'Weird')
# Out:
# "3"
# Weird

# %% [markdown]
# ##[Day 4: Logical Operators + Class vs. Instance!](https://www.hackerrank.com/contests/30-days-of-code/challenges/day-4-boolean-operators-class-vs-instance)

# %%
class Person:

    def __init__(self, initial_Age):
        if initial_Age < 0:
            print("This person is not valid, setting age to 0.")
            self.age = 0
        else:
            self.age = initial_Age

    def amIOld(self):
        if self.age < 13:
            print("You are young.")
        elif self.age >= 13 and self.age < 18:
            print("You are a teenager.")
        else:
            print("You are old.")

    def yearPasses(self):
        self.age += 1

# %%
T=int(raw_input())
for i in range(0,T):
    age=int(raw_input())         
    p=Person(age)  
    p.amIOld()
    for j in range(0,3):
        p.yearPasses();        
    p.amIOld();
    print ""
# Out:
# 3
# 12
# You are young.
# You are a teenager.
#
# 17
# You are a teenager.
# You are old.
#
# -10
# This person is not valid, setting age to 0.
# You are young.
# You are young.

# %% [markdown]
# ##[Day 5: Loops!](https://www.hackerrank.com/contests/30-days-of-code/challenges/day-5-loops)

# %%
for t in range(int(raw_input())):
    a, b, N = [int(i) for i in raw_input().split()]
    r = a+b
    for n in range(1, N):
        print r,
        r += (2**n) * b
    print r
# Out:
# 1
# 5 3 5
# 8 14 26 50 98

# %% [markdown]
# ##[Day 6: Let's Review!](https://www.hackerrank.com/contests/30-days-of-code/challenges/day-6-lets-review)

# %%
n = int(raw_input().strip())
for i in range (1,n+1):
    print ("#"*i).rjust(n)
# Out:
# 5
#     #
#    ##
#   ###
#  ####
# #####

# %% [markdown]
# ##[Day 7: Arrays!](https://www.hackerrank.com/contests/30-days-of-code/challenges/day-7-arrays)

# %%
raw_input()
print " ".join((raw_input().split())[::-1])
# Out:
# 1
# 1 23 456
# 456 23 1
